# %% [markdown]
# <a href="https://colab.research.google.com/github/hafidhsajid/PCVK_Genap_2021/blob/main/week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nomer 1

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Nomer 2
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')
plt.imshow(img)

# %%
#Nomer 3

kernel = np.ones((5,5), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910f98810>,
#  <matplotlib.image.AxesImage at 0x7f7910f741d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#Nomer 4
erosion = cv2.erode(img, kernel, iterations = 1)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910edcfd0>,
#  <matplotlib.image.AxesImage at 0x7f7910ea6a10>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#Nomer 5

kernel = np.ones((5,5), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910e43b10>,
#  <matplotlib.image.AxesImage at 0x7f7910d9a490>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#Nomer 6

kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910d82290>,
#  <matplotlib.image.AxesImage at 0x7f7910d50b50>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#Nomer 7

element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
erosion_dst = cv2.erode(img, element)
opening_dst = cv2.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening_dst), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910d7fad0>,
#  <matplotlib.image.AxesImage at 0x7f7910c8d450>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
#Nomer 8

element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
dilate_dst = cv2.dilate(img, element)
closing_dst = cv2.erode(dilate_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing_dst), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910c002d0>,
#  <matplotlib.image.AxesImage at 0x7f7910bcac90>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
#Nomer 9 (1)

kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3, 3))
cross3 = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910b1f6d0>,
#  <matplotlib.image.AxesImage at 0x7f7910b09410>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
#Nomer 9 (2)

kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (5, 5))
cross3 = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910a61950>,
#  <matplotlib.image.AxesImage at 0x7f7910a35f50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %%
#Nomer 10

kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
cross3 = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f79109fe510>,
#  <matplotlib.image.AxesImage at 0x7f7910970ad0>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 3x3'))

# %%
# Nomer 10 (2)


kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
cross3 = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910947a50>,
#  <matplotlib.image.AxesImage at 0x7f7910e03710>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 5x5'))

# %%
#Nomer 11

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 5))
cross3 = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7910c4a950>,
#  <matplotlib.image.AxesImage at 0x7f79108367d0>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 3x5'))

# %%
#Nomer 11 (2)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 7))
cross3 = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f79107a4610>,
#  <matplotlib.image.AxesImage at 0x7f791076dfd0>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))

# %%
#Nomer 12
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 7))
cross3 = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f79106dee10>,
#  <matplotlib.image.AxesImage at 0x7f79106aa750>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))
